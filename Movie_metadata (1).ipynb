# %%
#import numpy as np
#import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sns



import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (17, 5)
plt.rcParams.update({'font.size': 16})
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns


import sklearn.neighbors as skn
import sklearn.metrics as skm

# %%
#Read in
#Rows = 5043
mmdf = pd.read_csv('movie_metadata.csv')

# %%
mmdf.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
mmdf = mmdf.drop(columns = ['director_facebook_likes', 'actor_3_facebook_likes', 'actor_1_facebook_likes', 'cast_total_facebook_likes', 'facenumber_in_poster', 'actor_2_facebook_likes', 'movie_imdb_link', 'num_voted_users', 'num_critic_for_reviews', 'color','movie_facebook_likes','plot_keywords','aspect_ratio', 'num_user_for_reviews'], axis = 1)
#dropped all facebook like columns (director, actors 1-3, cast_total, movie_facebook_likes) because of multiple columns displaying values of 0
mmdf.head()
# Out:
#        director_name  duration      actor_2_name        gross  \
# 0      James Cameron     178.0  Joel David Moore  760505847.0
# 1     Gore Verbinski     169.0     Orlando Bloom  309404152.0
# 2         Sam Mendes     148.0      Rory Kinnear  200074175.0
# 3  Christopher Nolan     164.0    Christian Bale  448130642.0
# 4        Doug Walker       NaN        Rob Walker          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title          actor_3_name  \
# 0                                            Avatar              Wes Studi
# 1          Pirates of the Caribbean: At World's End         Jack Davenport
# 2                                           Spectre       Stephanie Sigman
# 3                             The Dark Knight Rises   Joseph Gordon-Levitt
# 4  Star Wars: Episode VII - The Force Awakens    ...                   NaN
#
#   language country content_rating       budget  title_year  imdb_score
# 0  English     USA          PG-13  237000000.0      2009.0         7.9
# 1  English     USA          PG-13  300000000.0      2007.0         7.1
# 2  English      UK          PG-13  245000000.0      2015.0         6.8
# 3  English     USA          PG-13  250000000.0      2012.0         8.5
# 4      NaN     NaN            NaN          NaN         NaN         7.1

# %%
cr = mmdf['content_rating'].value_counts().to_dict()
tv = cr['TV-14']
tv
# Out:
# 30

# %%
mmdf['content_rating'].value_counts()
# Out:
# R            2118
# PG-13        1461
# PG            701
# Not Rated     116
# G             112
# Unrated        62
# Approved       55
# TV-14          30
# TV-MA          20
# TV-PG          13
# X              13
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y7           1
# TV-Y            1
# Name: content_rating, dtype: int64

# %%
#Takes out rows rated 'TV-14'
#Rows = 5013
mmdf = mmdf[mmdf.content_rating != 'TV-14']
mmdf = mmdf[mmdf.content_rating != 'TV-Y']
mmdf = mmdf[mmdf.content_rating != 'TV-Y7']
mmdf = mmdf[mmdf.content_rating != 'M']
mmdf = mmdf[mmdf.content_rating != 'GP']
mmdf = mmdf[mmdf.content_rating != 'NC-17']
mmdf = mmdf[mmdf.content_rating != 'Passed']
mmdf = mmdf[mmdf.content_rating != 'TV-PG']
mmdf = mmdf[mmdf.content_rating != 'TV-MA']
mmdf = mmdf[mmdf.content_rating != 'x']
mmdf.head()
# Out:
#        director_name  duration      actor_2_name        gross  \
# 0      James Cameron     178.0  Joel David Moore  760505847.0
# 1     Gore Verbinski     169.0     Orlando Bloom  309404152.0
# 2         Sam Mendes     148.0      Rory Kinnear  200074175.0
# 3  Christopher Nolan     164.0    Christian Bale  448130642.0
# 4        Doug Walker       NaN        Rob Walker          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title          actor_3_name  \
# 0                                            Avatar              Wes Studi
# 1          Pirates of the Caribbean: At World's End         Jack Davenport
# 2                                           Spectre       Stephanie Sigman
# 3                             The Dark Knight Rises   Joseph Gordon-Levitt
# 4  Star Wars: Episode VII - The Force Awakens    ...                   NaN
#
#   language country content_rating       budget  title_year  imdb_score
# 0  English     USA          PG-13  237000000.0      2009.0         7.9
# 1  English     USA          PG-13  300000000.0      2007.0         7.1
# 2  English      UK          PG-13  245000000.0      2015.0         6.8
# 3  English     USA          PG-13  250000000.0      2012.0         8.5
# 4      NaN     NaN            NaN          NaN         NaN         7.1

# %%
mmdf['content_rating'].value_counts()
# Out:
# R            2118
# PG-13        1461
# PG            701
# Not Rated     116
# G             112
# Unrated        62
# Approved       55
# X              13
# TV-G           10
# Name: content_rating, dtype: int64

# %%
#prints remaining rows with nan values
n_nan = mmdf[0:].isna().sum()
print(n_nan)
# Out:
# director_name      45
# duration           14
# actor_2_name       13
# gross             806
# genres              0
# actor_1_name        7
# movie_title         0
# actor_3_name       23
# language           12
# country             3
# content_rating    303
# budget            433
# title_year         49
# imdb_score          0
# dtype: int64

# %%
#drop rows with nan values.
#Rows = 3761
mmdf = mmdf.dropna(how = 'any')
mmdf.head()
# Out:
#        director_name  duration      actor_2_name        gross  \
# 0      James Cameron     178.0  Joel David Moore  760505847.0
# 1     Gore Verbinski     169.0     Orlando Bloom  309404152.0
# 2         Sam Mendes     148.0      Rory Kinnear  200074175.0
# 3  Christopher Nolan     164.0    Christian Bale  448130642.0
# 5     Andrew Stanton     132.0   Samantha Morton   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title          actor_3_name language  \
# 0                                    Avatar              Wes Studi  English
# 1  Pirates of the Caribbean: At World's End         Jack Davenport  English
# 2                                   Spectre       Stephanie Sigman  English
# 3                     The Dark Knight Rises   Joseph Gordon-Levitt  English
# 5                               John Carter           Polly Walker  English
#
#   country content_rating       budget  title_year  imdb_score
# 0     USA          PG-13  237000000.0      2009.0         7.9
# 1     USA          PG-13  300000000.0      2007.0         7.1
# 2      UK          PG-13  245000000.0      2015.0         6.8
# 3     USA          PG-13  250000000.0      2012.0         8.5
# 5     USA          PG-13  263700000.0      2012.0         6.6

# %%
#Filter by movie years > 1985
mmdf = mmdf[mmdf.title_year >= 1985]
mmdf.head()
# Out:
#        director_name  duration      actor_2_name        gross  \
# 0      James Cameron     178.0  Joel David Moore  760505847.0
# 1     Gore Verbinski     169.0     Orlando Bloom  309404152.0
# 2         Sam Mendes     148.0      Rory Kinnear  200074175.0
# 3  Christopher Nolan     164.0    Christian Bale  448130642.0
# 5     Andrew Stanton     132.0   Samantha Morton   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title          actor_3_name language  \
# 0                                    Avatar              Wes Studi  English
# 1  Pirates of the Caribbean: At World's End         Jack Davenport  English
# 2                                   Spectre       Stephanie Sigman  English
# 3                     The Dark Knight Rises   Joseph Gordon-Levitt  English
# 5                               John Carter           Polly Walker  English
#
#   country content_rating       budget  title_year  imdb_score
# 0     USA          PG-13  237000000.0      2009.0         7.9
# 1     USA          PG-13  300000000.0      2007.0         7.1
# 2      UK          PG-13  245000000.0      2015.0         6.8
# 3     USA          PG-13  250000000.0      2012.0         8.5
# 5     USA          PG-13  263700000.0      2012.0         6.6

# %%
mmdf.set_index('movie_title', inplace = True)

# %%
mmdf.head()
# Out:
#                                                director_name  duration  \
# movie_title
# Avatar                                         James Cameron     178.0
# Pirates of the Caribbean: At World's End      Gore Verbinski     169.0
# Spectre                                           Sam Mendes     148.0
# The Dark Knight Rises                      Christopher Nolan     164.0
# John Carter                                   Andrew Stanton     132.0
#
#                                                actor_2_name        gross  \
# movie_title
# Avatar                                     Joel David Moore  760505847.0
# Pirates of the Caribbean: At World's End      Orlando Bloom  309404152.0
# Spectre                                        Rory Kinnear  200074175.0
# The Dark Knight Rises                        Christian Bale  448130642.0
# John Carter                                 Samantha Morton   73058679.0
#
#                                                                     genres  \
# movie_title
# Avatar                                     Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
# Spectre                                          Action|Adventure|Thriller
# The Dark Knight Rises                                      Action|Thriller
# John Carter                                        Action|Adventure|Sci-Fi
#
#                                               actor_1_name  \
# movie_title
# Avatar                                         CCH Pounder
# Pirates of the Caribbean: At World's End       Johnny Depp
# Spectre                                    Christoph Waltz
# The Dark Knight Rises                            Tom Hardy
# John Carter                                   Daryl Sabara
#
#                                                    actor_3_name language  \
# movie_title
# Avatar                                                Wes Studi  English
# Pirates of the Caribbean: At World's End         Jack Davenport  English
# Spectre                                        Stephanie Sigman  English
# The Dark Knight Rises                      Joseph Gordon-Levitt  English
# John Carter                                        Polly Walker  English
#
#                                           country content_rating       budget  \
# movie_title
# Avatar                                        USA          PG-13  237000000.0
# Pirates of the Caribbean: At World's End      USA          PG-13  300000000.0
# Spectre                                        UK          PG-13  245000000.0
# The Dark Knight Rises                         USA          PG-13  250000000.0
# John Carter                                   USA          PG-13  263700000.0
#
#                                            title_year  imdb_score
# movie_title
# Avatar                                         2009.0         7.9
# Pirates of the Caribbean: At World's End       2007.0         7.1
# Spectre                                        2015.0         6.8
# The Dark Knight Rises                          2012.0         8.5
# John Carter                                    2012.0         6.6

# %%
columnsTitles = ['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name','genres','content_rating','language', 'country','title_year','duration', 'budget','gross','imdb_score']
mmdf=mmdf[columnsTitles]
mmdf.head()
# Out:
#                                                director_name     actor_1_name  \
# movie_title
# Avatar                                         James Cameron      CCH Pounder
# Pirates of the Caribbean: At World's End      Gore Verbinski      Johnny Depp
# Spectre                                           Sam Mendes  Christoph Waltz
# The Dark Knight Rises                      Christopher Nolan        Tom Hardy
# John Carter                                   Andrew Stanton     Daryl Sabara
#
#                                                actor_2_name  \
# movie_title
# Avatar                                     Joel David Moore
# Pirates of the Caribbean: At World's End      Orlando Bloom
# Spectre                                        Rory Kinnear
# The Dark Knight Rises                        Christian Bale
# John Carter                                 Samantha Morton
#
#                                                    actor_3_name  \
# movie_title
# Avatar                                                Wes Studi
# Pirates of the Caribbean: At World's End         Jack Davenport
# Spectre                                        Stephanie Sigman
# The Dark Knight Rises                      Joseph Gordon-Levitt
# John Carter                                        Polly Walker
#
#                                                                     genres  \
# movie_title
# Avatar                                     Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End          Action|Adventure|Fantasy
# Spectre                                          Action|Adventure|Thriller
# The Dark Knight Rises                                      Action|Thriller
# John Carter                                        Action|Adventure|Sci-Fi
#
#                                           content_rating language country  \
# movie_title
# Avatar                                             PG-13  English     USA
# Pirates of the Caribbean: At World's End           PG-13  English     USA
# Spectre                                            PG-13  English      UK
# The Dark Knight Rises                              PG-13  English     USA
# John Carter                                        PG-13  English     USA
#
#                                            title_year  duration       budget  \
# movie_title
# Avatar                                         2009.0     178.0  237000000.0
# Pirates of the Caribbean: At World's End       2007.0     169.0  300000000.0
# Spectre                                        2015.0     148.0  245000000.0
# The Dark Knight Rises                          2012.0     164.0  250000000.0
# John Carter                                    2012.0     132.0  263700000.0
#
#                                                  gross  imdb_score
# movie_title
# Avatar                                     760505847.0         7.9
# Pirates of the Caribbean: At World's End   309404152.0         7.1
# Spectre                                    200074175.0         6.8
# The Dark Knight Rises                      448130642.0         8.5
# John Carter                                 73058679.0         6.6

# %%
def tidy_split(df, column, sep='|', keep=False):
    """
    Split the values of a column and expand so the new DataFrame has one split
    value per row. Filters rows where the column is missing.

    Params
    ------
    df : pandas.DataFrame
        dataframe with the column to split and expand
    column : str
        the column to split and expand
    sep : str
        the string used to split the column's values
    keep : bool
        whether to retain the presplit value as it's own row

    Returns
    -------
    pandas.DataFrame
        Returns a dataframe with the same columns as `df`.
    """
    indexes = list()
    new_values = list()
    df = df.dropna(subset=[column])
    for i, presplit in enumerate(df[column].astype(str)):
        values = presplit.split(sep)
        if keep and len(values) > 1:
            indexes.append(i)
            new_values.append(presplit)
        for value in values:
            indexes.append(i)
            new_values.append(value)
    new_df = df.iloc[indexes, :].copy()
    new_df[column] = new_values
    return new_df

# %%
mmdf_genre= tidy_split(mmdf,'genres', sep='|')

mmdf_genre.head()
# Out:
#                                             director_name actor_1_name  \
# movie_title
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Pirates of the Caribbean: At World's End   Gore Verbinski  Johnny Depp
#
#                                                actor_2_name    actor_3_name  \
# movie_title
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Pirates of the Caribbean: At World's End      Orlando Bloom  Jack Davenport
#
#                                               genres content_rating language  \
# movie_title
# Avatar                                        Action          PG-13  English
# Avatar                                     Adventure          PG-13  English
# Avatar                                       Fantasy          PG-13  English
# Avatar                                        Sci-Fi          PG-13  English
# Pirates of the Caribbean: At World's End      Action          PG-13  English
#
#                                           country  title_year  duration  \
# movie_title
# Avatar                                        USA      2009.0     178.0
# Avatar                                        USA      2009.0     178.0
# Avatar                                        USA      2009.0     178.0
# Avatar                                        USA      2009.0     178.0
# Pirates of the Caribbean: At World's End      USA      2007.0     169.0
#
#                                                 budget        gross  \
# movie_title
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Pirates of the Caribbean: At World's End   300000000.0  309404152.0
#
#                                            imdb_score
# movie_title
# Avatar                                            7.9
# Avatar                                            7.9
# Avatar                                            7.9
# Avatar                                            7.9
# Pirates of the Caribbean: At World's End          7.1

# %%
mmdf_genre['title_year']=mmdf_genre['title_year'].astype(int)

mmdf_genre.head()
# Out:
#                                             director_name actor_1_name  \
# movie_title
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Pirates of the Caribbean: At World's End   Gore Verbinski  Johnny Depp
#
#                                                actor_2_name    actor_3_name  \
# movie_title
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Pirates of the Caribbean: At World's End      Orlando Bloom  Jack Davenport
#
#                                               genres content_rating language  \
# movie_title
# Avatar                                        Action          PG-13  English
# Avatar                                     Adventure          PG-13  English
# Avatar                                       Fantasy          PG-13  English
# Avatar                                        Sci-Fi          PG-13  English
# Pirates of the Caribbean: At World's End      Action          PG-13  English
#
#                                           country  title_year  duration  \
# movie_title
# Avatar                                        USA        2009     178.0
# Avatar                                        USA        2009     178.0
# Avatar                                        USA        2009     178.0
# Avatar                                        USA        2009     178.0
# Pirates of the Caribbean: At World's End      USA        2007     169.0
#
#                                                 budget        gross  \
# movie_title
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Pirates of the Caribbean: At World's End   300000000.0  309404152.0
#
#                                            imdb_score
# movie_title
# Avatar                                            7.9
# Avatar                                            7.9
# Avatar                                            7.9
# Avatar                                            7.9
# Pirates of the Caribbean: At World's End          7.1

# %%
mmdf_genre=mmdf_genre[mmdf_genre.country =='USA']
mmdf_genre.head()
# Out:
#                                             director_name actor_1_name  \
# movie_title
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Avatar                                      James Cameron  CCH Pounder
# Pirates of the Caribbean: At World's End   Gore Verbinski  Johnny Depp
#
#                                                actor_2_name    actor_3_name  \
# movie_title
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Avatar                                     Joel David Moore       Wes Studi
# Pirates of the Caribbean: At World's End      Orlando Bloom  Jack Davenport
#
#                                               genres content_rating language  \
# movie_title
# Avatar                                        Action          PG-13  English
# Avatar                                     Adventure          PG-13  English
# Avatar                                       Fantasy          PG-13  English
# Avatar                                        Sci-Fi          PG-13  English
# Pirates of the Caribbean: At World's End      Action          PG-13  English
#
#                                           country  title_year  duration  \
# movie_title
# Avatar                                        USA        2009     178.0
# Avatar                                        USA        2009     178.0
# Avatar                                        USA        2009     178.0
# Avatar                                        USA        2009     178.0
# Pirates of the Caribbean: At World's End      USA        2007     169.0
#
#                                                 budget        gross  \
# movie_title
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Avatar                                     237000000.0  760505847.0
# Pirates of the Caribbean: At World's End   300000000.0  309404152.0
#
#                                            imdb_score
# movie_title
# Avatar                                            7.9
# Avatar                                            7.9
# Avatar                                            7.9
# Avatar                                            7.9
# Pirates of the Caribbean: At World's End          7.1

# %%
mmdf_genre['language'].value_counts()
# Out:
# English       8581
# Spanish         17
# Maya             4
# Bosnian          3
# Japanese         3
# Filipino         3
# None             2
# Dari             1
# Vietnamese       1
# Aramaic          1
# Name: language, dtype: int64

# %%
desc = mmdf_genre.describe()
desc
# Out:
#         title_year     duration        budget         gross   imdb_score
# count  8616.000000  8616.000000  8.616000e+03  8.616000e+03  8616.000000
# mean   2004.338092   109.089833  4.775949e+07  6.367693e+07     6.353412
# std       7.238818    20.929177  4.686870e+07  7.717881e+07     1.025179
# min    1985.000000    37.000000  2.180000e+02  7.030000e+02     1.600000
# 25%    1999.000000    95.000000  1.500000e+07  1.409530e+07     5.800000
# 50%    2005.000000   105.000000  3.200000e+07  3.811948e+07     6.400000
# 75%    2010.000000   119.000000  6.500000e+07  8.242287e+07     7.000000
# max    2016.000000   330.000000  3.000000e+08  7.605058e+08     9.300000

# %%
plt.scatter(x=mmdf['title_year'], y=mmdf['imdb_score'], s=30)
plt.xlabel('Year')
plt.ylabel('IMDB Score')
plt.title("IMDB scores for movies of 'X' year")
# Out:
# Text(0.5, 1.0, "IMDB scores for movies of 'X' year")

# %%
plt.scatter(x=mmdf['imdb_score'], y=mmdf['gross'], s=30)
plt.ylabel('Gross in millions')
plt.xlabel('IMDB Score')
# Out:
# Text(0.5, 0, 'IMDB Score')

# %%
plt.scatter(x=mmdf['imdb_score'], y=mmdf['budget'], s=30)
plt.xlabel('IMDB Score')
plt.ylabel('Budget')
plt.title('IMDB Scoe VS. Budget')
# Out:
# Text(0.5, 1.0, 'IMDB Scoe VS. Budget')

# %%
corr = mmdf_genre.corr()
corr
# Out:
#             title_year  duration    budget     gross  imdb_score
# title_year    1.000000 -0.007616  0.246187  0.115894   -0.013800
# duration     -0.007616  1.000000  0.300402  0.264414    0.369467
# budget        0.246187  0.300402  1.000000  0.663758    0.121829
# gross         0.115894  0.264414  0.663758  1.000000    0.290577
# imdb_score   -0.013800  0.369467  0.121829  0.290577    1.000000

# %%
plt.hist(x=mmdf['title_year'])
plt.xlabel('Title Year')
plt.ylabel('Amount')
plt.title('Number of Movies in Dataset Released Each Year')
# Out:
# Text(0.5, 1.0, 'Number of Movies in Dataset Released Each Year')

# %%
fig=pd.plotting.scatter_matrix(mmdf_genre)

# %%
major_counts= mmdf_genre['genres'].value_counts()
major_counts.plot.bar()
plt.xlabel('Genre Category')
plt.ylabel('Amount')
plt.title('Total Number of Each Genre Caegory in Dataset ')
# Out:
# Text(0.5, 1.0, 'Total Number of Each Genre Caegory in Dataset ')

# %%
a=(mmdf_genre['budget'].loc[mmdf_genre.title_year == 2008])
a.plot.bar()

# %%
plt.boxplot(mmdf_genre['title_year'])
plt.ylabel('Title Year')
plt.title('Distribution of Films in our Dataset')
# Out:
# Text(0.5, 1.0, 'Distribution of Films in our Dataset')

# %%
plt.boxplot(mmdf_genre['imdb_score'])
plt.ylabel('IMDB Score')
plt.title('Spread of IMDB Scores in our dataset')
# Out:
# Text(0.5, 1.0, 'Spread of IMDB Scores in our dataset')

# %%
plt.boxplot(mmdf_genre['duration'])
plt.ylabel('Duration (minutes)')
plt.title('Spread of Duration lenghts of movies in our dataset')
# Out:
# Text(0.5, 1.0, 'Spread of Duration lenghts of movies in our dataset')

# %%
plt.scatter(x=mmdf['duration'], y=mmdf['budget'], s=30)
plt.xlabel('Duration (minutes)')
plt.ylabel('Budget')

plt.title('Duration and Budget Relationship')
# Out:
# Text(0.5, 1.0, 'Duration and Budget Relationship')

# %%
plt.scatter(x=mmdf['gross'], y=mmdf['budget'], s=30)
plt.title("Gross VS Budget")
plt.xlabel('Gross')
plt.ylabel('Budget')
# Out:
# Text(0, 0.5, 'Budget')

# %%
genre_counts=(mmdf_genre['content_rating'].value_counts())
genre_counts.plot.bar()
plt.xlabel('Content Rating Categories')
plt.ylabel("Amount")
plt.title("Total Number of Movies per Content Rating")
# Out:
# Text(0.5, 1.0, 'Total Number of Movies per Content Rating')

# %%
plt.hist(mmdf_genre['gross'].loc[mmdf_genre['genres']=="Drama"])
plt.title("Gross Histogram for Movies with Drama as a Genre")
plt.xlabel('Gross')
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %%
plt.hist(mmdf_genre['gross'].loc[mmdf_genre['genres']=="Action"])
plt.title("Gross Histogram for Movies with Action as a Genre")
plt.xlabel('Gross')
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')

# %%
plt.hist(mmdf_genre['gross'].loc[mmdf_genre['genres']=="Comedy"])
plt.title("Gross Histogram for Movies with Comedy as a Genre")
plt.xlabel('Gross')
plt.ylabel("Number of Movies")
# Out:
# Text(0, 0.5, 'Number of Movies')
